# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy
import jinja2

# %% [markdown]
# # Load data

# %%
train_data_frame = pd.read_csv("../../data/train.csv")
test_data_frame = pd.read_csv("../../data/test.csv")

# %%
train_data_frame.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Dimensions of the datasets

# %%
print(f"Training set shape: {train_data_frame.shape}")
print(f"Test set shape: {test_data_frame.shape}")
# Out:
# Training set shape: (1460, 81)
# Test set shape: (1459, 80)

# %% [markdown]
# Histogram of feature data types

# %%
train_data_frame.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# Descriptive statistics

# %%
train_data_frame.describe().transpose()
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %% [markdown]
# Output variables investigation

# %%
train_data_frame['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
print(f"Skewness: {train_data_frame['SalePrice'].skew()}")
print(f"Kurtosis: {train_data_frame['SalePrice'].kurt()}")
# Out:
# Skewness: 1.8828757597682129
# Kurtosis: 6.536281860064529

# %%
hist, bins = np.histogram(train_data_frame['SalePrice'].to_numpy(), bins=50,density=True)
width = 0.7 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
plt.bar(center, hist, align='center', width=width, zorder=1)

# density plot
train_data_frame['SalePrice'].plot.kde(zorder=2, color='C1')
plt.show()

# %% [markdown]
# Correlation between numerical variables

# %%
corr = train_data_frame.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_24627_row0_col0, #T_24627_row1_col1, #T_24627_row2_col2, #T_24627_row3_col3, #T_24627_row4_col4, #T_24627_row5_col5, #T_24627_row6_col6, #T_24627_row7_col7, #T_24627_row8_col8, #T_24627_row9_col9, #T_24627_row10_col10, #T_24627_row11_col11, #T_24627_row12_col12, #T_24627_row13_col13, #T_24627_row14_col14, #T_24627_row15_col15, #T_24627_row16_col16, #T_24627_row17_col17, #T_24627_row18_col18, #T_24627_row19_col19, #T_24627_row20_col20, #T_24627_row21_col21, #T_24627_row22_col22, #T_24627_row23_col23, #T_24627_row24_col24, #T_24627_row25_col25, #T_24627_row26_col26, #T_24627_row27_col27, #T_24627_row28_col28, #T_24627_row29_col29, #T_24627_row30_col30, #T_24627_row31_col31, #T_24627_row32_col32, #T_24627_row33_col33, #T_24627_row34_col34, #T_24627_row35_col35, #T_24627_row36_col36, #T_24627_row37_col37 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...

# %%
correlated_features = corr['SalePrice'].sort_values(ascending = False).head(10)
correlated_features
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %%
y = train_data_frame['SalePrice'].to_numpy()
for key in dict(correlated_features).keys():
    x = train_data_frame[key].to_numpy()
    fig1, ax = plt.subplots()
    ax.scatter(x, y)
    ax.set_title(f"{key} vs SalePrice
    plt.show()
# Out:
# <ipython-input-67-136401658869>:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax = plt.subplots()
